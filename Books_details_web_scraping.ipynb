# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from concurrent.futures import ThreadPoolExecutor
import httplib2

def scrape_page_and_get_links(url):
    http = httplib2.Http()
    response, content = http.request(url)
    page = content.decode('utf-8')

    data = BeautifulSoup(page, 'html.parser')
    book_link_tags = data.find_all('a', attrs={'class': 'bookTitle'})
    book_links = ['https://www.goodreads.com/' + link['href'] for link in book_link_tags]
    return book_links

if __name__ == '__main__':
    all_pages = []
    for serial in range(1, 100, 1):
        page = f"https://www.goodreads.com/list/show/19106.MUST_READS_?page={serial}"
        all_pages.append(page)

    # Use multithreading with ThreadPoolExecutor
    num_threads = 10  # You can adjust the number of threads as needed
    with ThreadPoolExecutor(max_workers=num_threads) as executor:
        results = list(executor.map(scrape_page_and_get_links, all_pages))

    # Flatten the results into a single list of book links
    book_links = [link for sublist in results for link in sublist]

# %%
len(book_links)
# Out:
# 9699

# %%
from concurrent.futures import ThreadPoolExecutor
import time

def scrape_book_details(link):
    try:
        response = requests.get(link)
        response.raise_for_status()  # Raise an exception if the response status code is not 200

        book_data = BeautifulSoup(response.text, 'html.parser')

        title = book_data.find('h1', attrs={'class': 'Text Text__title1'})
        author = book_data.find('span', attrs={'class': 'ContributorLink__name'})
        rating = book_data.find('div', attrs={'class': 'RatingStatistics__rating'})
        no_of_ratings = book_data.find('div', attrs={'class': 'RatingStatistics__meta'})
        description = book_data.find('div', attrs={'class': 'DetailsLayoutRightParagraph__widthConstrained'})
        genres = book_data.find_all('span', attrs={'class': 'BookPageMetadataSection__genreButton'})

        # Extract the text from each element (if found) or set as None if not found
        title_text = title.text.strip() if title else None
        author_text = author.text.strip() if author else None
        rating_text = rating.text.strip() if rating else None
        no_of_ratings_text = no_of_ratings.text.strip() if no_of_ratings else None
        description_text = description.text.strip() if description else None
        genres_list = [genre.text.strip() for genre in genres] if genres else []

        # Create a dictionary for the current book
        book_dict = {
            'Title': title_text,
            'Author': author_text,
            'Rating': rating_text,
            'Number of Ratings': no_of_ratings_text,
            'Description': description_text,
            'Genres': genres_list
        }

        return book_dict
    except requests.exceptions.RequestException as e:
        print(f"Error while scraping {link}: {e}")
        return None

if __name__ == '__main__':
    # Your list of book links
    your_book_links = book_links

    # Use multithreading to scrape book details for each link
    num_threads = 300  # Adjust this number based on server capacity and your system capabilities

    # Introduce a delay of 2 seconds between each request
    time_delay = 2

    with ThreadPoolExecutor(max_workers=num_threads) as executor:
        book_details = list(executor.map(scrape_book_details, your_book_links))
        time.sleep(time_delay)  # Add a delay between requests to be considerate to the server
# Out:
# Error while scraping https://www.goodreads.com//book/show/41865.Twilight: 504 Server Error: Gateway Time-out for url: https://www.goodreads.com//book/show/41865.TwilightError while scraping https://www.goodreads.com//book/show/231804.The_Outsiders: 504 Server Error: Gateway Time-out for url: https://www.goodreads.com//book/show/231804.The_Outsiders
#
# Error while scraping https://www.goodreads.com//book/show/6752378-city-of-fallen-angels: 504 Server Error: Gateway Time-out for url: https://www.goodreads.com//book/show/6752378-city-of-fallen-angels
# Error while scraping https://www.goodreads.com//book/show/2800905-the-summoning: 504 Server Error: Gateway Time-out for url: https://www.goodreads.com//book/show/2800905-the-summoning
# Error while scraping https://www.goodreads.com//book/show/32191737-grunt: HTTPSConnectionPool(host='www.goodreads.com', port=443): Max retries exceeded with url: //book/show/32191737-grunt (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x000002065744FE90>, 'Connection to www.goodreads.com timed out. (connect timeout=None)'))
# Error while scraping https://www.goodreads.com//book/show/27259009-average-joe-and-the-extraordinaires: 502 Server Error: Bad Gateway for url: https://www.goodreads.com//book/show/27259009-average-joe-and-the-extraordinaires
# Error while scraping https://www.goodreads.com//book/show/8695.The_Restaurant_at_the_End_of_the_Universe: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Error while scraping https://www.goodreads.com//book/show
('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Error while scraping https://www.goodreads.com//book/show/43982433-someone-we-know: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Error while scraping https://www.goodreads.com//book/show/21569527-the-heart-of-betrayal: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
# Error while scraping https://www.goodreads.com//book/show/34964998-when-they-call-you-a-terrorist: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Error while scraping https://www.goodreads.com//book/show/776.Buddhism_Plain_and_Simple: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
# Error while scraping https://www.goodreads.com//book/show/62530.Thud_: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Error while scraping https://www.goodreads.com//book/show/25739007-charlotte-bront: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Error while scraping https://www.goodreads.com//book/show/10532477-heat-rises: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Error while scraping https://www.goodreads.com//book/show/18368537-gabriel-s-redemption: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Error while scraping https://www.goodreads.com//book/show/15817351-broken-dove: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Error while scraping https://www.goodreads.com//book/show/32580398-perfect-remains: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Error while scraping https://www.goodreads.com//book/show/12679709-the-life-and-opinions-of-tristram-shandy-gentleman: HTTPSConnectionPool(host='www.goodreads.com', port=443): Max retries exceeded with url: //book/show/12679709-the-life-and-opinions-of-tristram-shandy-gentleman (Caused by SSLError(SSLEOFError(8, 'EOF occurred in violation of protocol (_ssl.c:1002)')))
# Error while scraping https://www.goodreads.com//book/show/15810336-wide-awake: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Error while scraping https://www.goodreads.com//book/show/25634298-remember: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
# Error while scraping https://www.goodreads.com//book/show/12996659-a-dangerous-harbor: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Error while scraping https://www.goodreads.com//book/show/15726371-the-tutor-s-daughter: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
# Error while scraping https://www.goodreads.com//book/show/10681429-shaedes-of-gray: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Error while scraping https://www.goodreads.com//book/show/748989.From_Doon_With_Death: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
# Error while scraping https://www.goodreads.com//book/show/9436746-10th-anniversary: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Error while scraping https://www.goodreads.com//book/show/58340902-strong-female-lead: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
# Error while scraping https://www.goodreads.com//book/show/10680329-a-trick-of-the-light: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
# Error while scraping https://www.goodreads.com//book/show/52346471-firekeeper-s-daughter: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Error while scraping https://www.goodreads.com//book/show/30095464-the-bone-witch: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Error while scraping https://www.goodreads.com//book/show/58375739-will: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Error while scraping https://www.goodreads.com//book/show/545061.The_Worst_Witch_All_at_Sea: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
# Error while scraping https://www.goodreads.com//book/show/23489258-second-debt: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Error while scraping https://www.goodreads.com//book/show/34323570-furyborn: HTTPSConnectionPool(host='www.goodreads.com', port=443): Max retries exceeded with url: //book/show/34323570-furyborn (Caused by SSLError(SSLEOFError(8, 'EOF occurred in violation of protocol (_ssl.c:1002)')))
# Error while scraping https://www.goodreads.com//book/show/32507.Chasing_the_Dime: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Error while scraping https://www.goodreads.com//book/show/12202480-catalyst: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Error while scraping https://www.goodreads.com//book/show/24359128-dirty-ties: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
# Error while scraping https://www.goodreads.com//book/show/5056084-wings: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
# Error while scraping https://www.goodreads.com//book/show/17607.All_About_Love: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
# Error while scraping https://www.goodreads.com//book/show/34352739-can-t-find-love: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
# Error while scraping https://www.goodreads.com//book/show/23298686-his: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
# Error while scraping https://www.goodreads.com//book/show/35137915-i-am-i-am-i-am: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
# Error while scraping https://www.goodreads.com//book/show/2855034-nation: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Error while scraping https://www.goodreads.com//book/show/606926.The_Case_of_the_Left_Handed_Lady: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Error while scraping https://www.goodreads.com//book/show/11997316-uprising: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Error while scraping https://www.goodreads.com//book/show/10772848-into-the-heart-of-the-country: HTTPSConnectionPool(host='www.goodreads.com', port=443): Max retries exceeded with url: //book/show/10772848-into-the-heart-of-the-country (Caused by SSLError(SSLEOFError(8, 'EOF occurred in violation of protocol (_ssl.c:1002)')))
# Error while scraping https://www.goodreads.com//book/show/20821032-victoria: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
# Error while scraping https://www.goodreads.com//book/show/51591602-she-s-too-pretty-to-burn: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
# Error while scraping https://www.goodreads.com//book/show/16065004-shadows-of-self: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Error while scraping https://www.goodreads.com//book/show/33986447-insignificant-events-in-the-life-of-a-cactus: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
# Error while scraping https://www.goodreads.com//book/show/36071.First_Things_First: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Error while scraping https://www.goodreads.com//book/show/2054761.The_Snowball: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Error while scraping https://www.goodreads.com//book/show/29589074-truly-devious: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
# Error while scraping https://www.goodreads.com//book/show/67920.Sybil: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Error while scraping https://www.goodreads.com//book/show/6503161-hungry-for-you: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Error while scraping https://www.goodreads.com//book/show/13426114-the-honest-truth-about-dishonesty: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Error while scraping https://www.goodreads.com//book/show/16117911-the-iron-king: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Error while scraping https://www.goodreads.com//book/show/25241653-hero-of-the-empire: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
# Error while scraping https://www.goodreads.com//book/show/21899546-love-in-english: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Error while scraping https://www.goodreads.com//book/show/43385933-swipe-to-unlock: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Error while scraping https://www.goodreads.com//book/show/23562898-browsings: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Error while scraping https://www.goodreads.com//book/show/350890.Man_s_Search_for_Meaning: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))Error while scraping https://www.goodreads.com//book/show/659469.The_Hobbit: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
#
# Error while scraping https://www.goodreads.com//book/show/355916.Physik: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Error while scraping https://www.goodreads.com//book/show/16335.The_Mystery_of_the_Blue_Train: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Error while scraping https://www.goodreads.com//book/show/129117.The_Spellman_Files: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Error while scraping https://www.goodreads.com//book/show/5623269-the-friday-society: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
# Error while scraping https://www.goodreads.com//book/show/55339001-hairpin-bridge: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Error while scraping https://www.goodreads.com//book/show/18484563-storm-warning: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Error while scraping https://www.goodreads.com//book/show/42036538-gideon-the-ninth: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Error while scraping https://www.goodreads.com//book/show/205330.There_Was_an_Old_Lady_Who_Swallowed_a_Fly: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Error while scraping https://www.goodreads.com//book/show/23002756-like: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
# Error while scraping https://www.goodreads.com//book/show/12326407-the-lyre-of-orpheus: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Error while scraping https://www.goodreads.com//book/show/6452806-true-compass: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
# Error while scraping https://www.goodreads.com//book/show/11890816-the-gods-of-gotham: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Error while scraping https://www.goodreads.com//book/show/582070.Tallchief: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Error while scraping https://www.goodreads.com//book/show/18513769-the-valley-came-alive---vol-iii: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))Error while scraping https://www.goodreads.com//book/show/4583888-pride: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
#
# Error while scraping https://www.goodreads.com//book/show/22571540-the-stranger: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))

# %%
len(book_details)
# Out:
# 9699

# %%
# Filter out the None values from book_details
book_details = [book for book in book_details if book is not None]

# Create the DataFrame
df = pd.DataFrame(book_details)

# %%
df = df.dropna(how='any')

# %%
df.shape
# Out:
# (2531, 6)

# %%
df_2 = pd.read_csv('book_details.csv')

# %%
final_df = pd.concat([df,df_2])

# %%
final_df = final_df.drop_duplicates(subset='Title')

# %%
final_df.to_csv('book_details.csv',index=False)

# %%
final_df.shape
# Out:
# (13324, 6)
